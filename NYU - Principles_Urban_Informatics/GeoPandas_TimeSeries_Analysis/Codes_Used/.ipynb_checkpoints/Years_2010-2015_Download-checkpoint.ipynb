# %% [markdown]
# #### Achilles E A Saxby
# #### aes807
# #### Suppliment Code
# #### Downloading the files for years (2010 to 2015)

# %%
# !for ((y=10; y<=15; y+=1)); do wget ftp://ftp.census.gov/econ20$y\/CBP_CSV/zbp$y\totals.zip; done
# Out:
# --2016-11-29 14:48:29--  ftp://ftp.census.gov/econ2010/CBP_CSV/zbp10totals.zip
#            => “zbp10totals.zip”
# Resolving ftp.census.gov... 148.129.75.35, 2610:20:2010:a09:1000:0:9481:4b23
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /econ2010/CBP_CSV ... done.
# ==> SIZE zbp10totals.zip ... 797534
# ==> PASV ... done.    ==> RETR zbp10totals.zip ... done.
# Length: 797534 (779K) (unauthoritative)
#
# 100%[======================================>] 797,534      507K/s   in 1.5s
#
# 2016-11-29 14:48:31 (507 KB/s) - “zbp10totals.zip” saved [797534]
#
# --2016-11-29 14:48:31--  ftp://ftp.census.gov/econ2011/CBP_CSV/zbp11totals.zip
#            => “zbp11totals.zip”
# Resolving ftp.census.gov... 148.129.75.35, 2610:20:2010:a09:1000:0:9481:4b23
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ...
# ...
