# %% [markdown]
# ## Achilles E A Saxby
# ## aes807
#
# #### Generating Random Data (from anywhere) and plotting using the matplotlib directory
# #### Random Data generated from Mockaroo website - Gender/Country-USA/Time_Zone - Added into the folder
# #### The plot to follow the rules and regulations mentioned in the UI_PUI2016_Slides directory of the instructor's github account.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv
from collections import Counter
from itertools import chain

from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pwd
# Out:
# '/wingrdp/homedirs/aes807/PUI2016_aes807/HW7_aes807'

# %% [markdown]
# ### Plot 1

# %%
df = pd.read_csv('Mockaroo_Random_Data.csv')
df.head()
# Out:
#    Gender        Country            Time-Zone
# 0  Female  United States       America/Denver
# 1    Male  United States  America/Los_Angeles
# 2  Female  United States     America/New_York
# 3    Male  United States      America/Chicago
# 4    Male  United States  America/Los_Angeles

# %%
df['Country'][df['Country'] == 'United States'] = None
df['Country'] = df['Country'].astype(float)

# %%
df.head()
# Out:
#    Gender  Country            Time-Zone
# 0  Female      NaN       America/Denver
# 1    Male      NaN  America/Los_Angeles
# 2  Female      NaN     America/New_York
# 3    Male      NaN      America/Chicago
# 4    Male      NaN  America/Los_Angeles

# %%
df.fillna(value = 1, method = None, axis = 1, inplace = True)
df.head()
# Out:
#    Gender  Country            Time-Zone
# 0  Female      1.0       America/Denver
# 1    Male      1.0  America/Los_Angeles
# 2  Female      1.0     America/New_York
# 3    Male      1.0      America/Chicago
# 4    Male      1.0  America/Los_Angeles

# %%
df['Time-Zone'][:]
# Out:
# 0           America/Denver
# 1      America/Los_Angeles
# 2         America/New_York
# 3          America/Chicago
# 4      America/Los_Angeles
# 5         America/New_York
# 6         America/New_York
# 7         America/New_York
# 8      America/Los_Angeles
# 9         America/New_York
# 10          America/Denver
# 11         America/Chicago
# 12        America/New_York
# 13         America/Chicago
# 14        America/New_York
# 15     America/Los_Angeles
# 16        America/New_York
# 17     America/Los_Angeles
# 18         America/Chicago
# 19        America/New_York
# 20         America/Phoenix
# 21        America/New_York
# 22         America/Chicago
# 23        America/New_York
# 24        America/New_York
# 25           America/Boise
# 26        Pacific/Honolulu
# 27        America/New_York
# 28         America/Chicago
# 29         America/Chicago
#               ...
# 970       America/New_York
# 971       America/New_York
# 972        America/Phoenix
# ...

# %%
df_counts = df['Time-Zone'].value_counts()
df_counts[:]
# Out:
# America/New_York                420
# America/Chicago                 303
# America/Los_Angeles             148
# America/Denver                   51
# America/Phoenix                  31
# America/Detroit                  16
# America/Kentucky/Louisville      11
# America/Indiana/Indianapolis      7
# Pacific/Honolulu                  7
# America/Boise                     3
# America/Kentucky/Monticello       2
# America/Anchorage                 1
# Name: Time-Zone, dtype: int64

# %%
ax = df_counts[:].plot(x='Time-Zone', y='Counts', kind='barh', figsize=(7, 7), 
                       fontsize=14, color='Red', rot = 0)
ax.set_xlabel("Total Counts of the Time-Zones", fontsize = 13, fontweight = 'bold')
ax.set_title("Plotting of the Total Time-Zones in America from Randomized Data"
             , fontsize = 13, fontweight = 'bold')
plt.text(0,-2.5, 'Figure 1 : The Total Time-Zones that have been collected from the Randomly Generated Data'
         ,fontsize = 10, fontweight = 'bold')
plt.legend(loc = 'upper right')

# %% [markdown]
# This is the plotting of different time-zones recovered from data that was randomly downlaoded and stored for further reference.

# %%
with open('Mockaroo_Random_Data.csv') as csvfile:
    next(csvfile)
    counts = Counter(chain.from_iterable(csv.reader(csvfile)))

print("Total male = {}".format(counts["Male"]))
print("Total female = {}".format(counts["Female"]))
# Out:
# Total male = 518
# Total female = 482

# %% [markdown]
# ### Plot 2

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for c, z in zip(['r', 'g', 'b', 'y'], [30, 20, 10, 0]):
    xs = np.arange(20)
    ys = np.random.rand(20)

    # You can provide either a single color or an array. To demonstrate this,
    # the first bar of each set will be colored cyan.
    cs = [c] * len(xs)
    cs[0] = 'c'
    ax.bar(xs, ys, zs=z, zdir='y', color=cs, alpha=0.8)

ax.set_xlabel('X', fontsize = 11, fontweight = 'bold')
ax.set_ylabel('Y', fontsize = 11, fontweight = 'bold')
ax.set_zlabel('Z', fontsize = 11, fontweight = 'bold')
ax.set_title("Plotting Random Data", fontsize = 13, fontweight = 'bold')
plt.show()

# %% [markdown]
# #### Figure 2: Randomly Plotted Data - Trying to plot a 3-D bar chart.
#
# This is a randomly generated 3-d bar plot.
