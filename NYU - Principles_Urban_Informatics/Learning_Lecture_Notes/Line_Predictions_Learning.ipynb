# %%
import numpy as np
import pylab as pl
# %pylab inline

import statsmodels.api as sm

np.random.seed(123)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/rh/anaconda/root/lib/python2.7/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
x = np.arange(0.0,100.0)
a = np.random.rand(2)
a
# Out:
# array([ 0.69646919,  0.28613933])

# %%
def line(a, x):
    '''
    this is supposed to be a docstring
    this is supposed to tell the reader what is happenning here
    check how to write a docstring to learn this better
    
    '''
    #y = a[0] * x + a[0]
    y = a[0] * x + a[1]
    return y

print line(a, x)
# Out:
# [  0.28613933   0.98260852   1.67907771   2.37554689   3.07201608
#    3.76848526   4.46495445   5.16142363   5.85789282   6.55436201
#    7.25083119   7.94730038   8.64376956   9.34023875  10.03670793
#   10.73317712  11.4296463   12.12611549  12.82258468  13.51905386
#   14.21552305  14.91199223  15.60846142  16.3049306   17.00139979
#   17.69786897  18.39433816  19.09080735  19.78727653  20.48374572
#   21.1802149   21.87668409  22.57315327  23.26962246  23.96609165
#   24.66256083  25.35903002  26.0554992   26.75196839  27.44843757
#   28.14490676  28.84137594  29.53784513  30.23431432  30.9307835
#   31.62725269  32.32372187  33.02019106  33.71666024  34.41312943
#   35.10959861  35.8060678   36.50253699  37.19900617  37.89547536
#   38.59194454  39.28841373  39.98488291  40.6813521   41.37782129
#   42.07429047  42.77075966  43.46722884  44.16369803  44.86016721
#   45.5566364   46.25310558  46.94957477  47.64604396  48.34251314
# ...

# %%
pl.plot(x, line(a, x),'bo')

# %%
# ?sm.OLS()

# %%
# regress = sm.OLS(y,x)

# %%
x_new = sm.add_np.arange(0.0, 20, 0.1)
print x_new, np.arange(0.0, 20, 0.1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-dcc00d229c5e> in <module>()
# ----> 1 x_new = sm.add_np.arange(0.0, 20, 0.1)
#       2 print x_new, np.arange(0.0, 20, 0.1)
#
# AttributeError: 'module' object has no attribute 'add_np'

# %%
pl.plot(x, line(a, x), 'bo')
pl.plot(x_new, regress.predict(x_new), 'go')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-c78299b661e6> in <module>()
#       2
#       3 pl.plot(x, line(a, x), 'bo')
# ----> 4 pl.plot(x_new, regress.predict(x_new), 'go')
#
# NameError: name 'regress' is not defined
