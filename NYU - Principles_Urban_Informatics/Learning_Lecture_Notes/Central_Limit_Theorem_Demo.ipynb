# %%
from __future__ import print_function #always has to be the first command - so that it changes the default at the start
import numpy as np
import pylab as pl
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#n - 10 and 2000 range - sample
#5 different distributions
#in homework choose all distributions to have the same means
#in chisquare - mean is the same as degrees of freedom - and python runs it
#check wiki always

np.random.chisquare?

np.random.seed(5762)

# %%
chisq = np.random.chisquare(100, 20) #degrees of freedom as first argument - #size as second
chisq
# Out:
# array([  85.03652731,   85.57320839,   99.96982318,  115.96419697,
#          99.57085096,  100.31969903,  104.90325332,   97.41606825,
#          99.97676365,  119.30244393,   79.07753796,   98.83476789,
#         119.14802708,  101.47094787,  107.21498784,   79.60045228,
#          96.64994932,  111.84185856,   87.43269083,  115.77692045])

# %%
pl.hist(chisq)
# Out:
# (array([ 2.,  2.,  1.,  0.,  3.,  5.,  2.,  0.,  1.,  4.]),
#  array([  79.07753796,   83.10002856,   87.12251916,   91.14500975,
#           95.16750035,   99.18999095,  103.21248154,  107.23497214,
#          111.25746274,  115.27995333,  119.30244393]),
#  <a list of 10 Patch objects>)

# %%
chisq2 = np.random.chisquare(100, 2000)
pl.hist(chisq2)
# Out:
# (array([  55.,  234.,  475.,  504.,  371.,  243.,   85.,   24.,    6.,    3.]),
#  array([  65.97791832,   75.38360275,   84.78928718,   94.19497161,
#          103.60065603,  113.00634046,  122.41202489,  131.81770932,
#          141.22339374,  150.62907817,  160.0347626 ]),
#  <a list of 10 Patch objects>)

# %%
#homework - for loop that runs a 100 times for 100 distributions and gets the mean for each and plots it

# %%
size = (2000 / np.array(range(1,101)))
size
# Out:
# array([2000, 1000,  666,  500,  400,  333,  285,  250,  222,  200,  181,
#         166,  153,  142,  133,  125,  117,  111,  105,  100,   95,   90,
#          86,   83,   80,   76,   74,   71,   68,   66,   64,   62,   60,
#          58,   57,   55,   54,   52,   51,   50,   48,   47,   46,   45,
#          44,   43,   42,   41,   40,   40,   39,   38,   37,   37,   36,
#          35,   35,   34,   33,   33,   32,   32,   31,   31,   30,   30,
#          29,   29,   28,   28,   28,   27,   27,   27,   26,   26,   25,
#          25,   25,   25,   24,   24,   24,   23,   23,   23,   22,   22,
#          22,   22,   21,   21,   21,   21,   21,   20,   20,   20,   20,
#          20])

# %%
#append stuffs things into lists

chidist = []
for i in range(0, len(size)):
    chidist.append(np.random.chisquare(100, size[i]))

# %%
chidist
# Out:
# [array([  90.84655335,  114.39078653,   90.33690876, ...,  108.79319988,
#           85.96572536,   85.66412765]),
#  array([  96.48083822,  137.49271156,   87.67268489,   89.06191164,
#          141.22848313,  118.8214984 ,   94.86718166,  124.20516785,
#           77.3559228 ,   91.36293721,   98.506597  ,   98.9268649 ,
#          132.58013827,   84.22727864,  107.86511373,   95.72626116,
#          105.95734177,  109.26304627,   91.26258097,   96.6419804 ,
#           96.03732799,  105.80879725,   89.95563628,  104.13194148,
#           96.7994279 ,   94.82425679,  102.99577502,  108.94071153,
#           98.48402056,  103.18238054,   97.61487639,  102.47387077,
#          106.60851841,   87.75753433,  113.52028594,   99.44072874,
#          103.11645726,   82.41144806,  112.89302596,   95.53974393,
#          116.68714423,  123.89486166,  128.24042936,  108.07563466,
#           83.95164429,   85.13604213,   96.433243  ,  109.35367056,
# ...

# %%
np.array(chidist).shape
# Out:
# (100,)

# %%
chidist[0]
# Out:
# array([  90.84655335,  114.39078653,   90.33690876, ...,  108.79319988,
#          85.96572536,   85.66412765])

# %%
type(chidist[0])
# Out:
# numpy.ndarray

# %%
chimeans = []
for i in range(0 , len(size)):
    chimeans.append(chidist[i].mean())

# %%
chimeans
# Out:
# [100.20325401678951,
#  100.41063486981129,
#  99.644855518669132,
#  99.948208411493283,
#  100.24871908628093,
#  99.961279748862196,
#  99.258799368257741,
#  99.037065034591492,
#  101.32949228428357,
#  100.70374582283719,
#  98.902295532658172,
#  101.30809141977612,
#  99.867162966649701,
#  103.02075066199508,
#  97.920293036182798,
#  100.24388562132287,
#  101.23796927856264,
#  97.484115443440558,
#  102.01822886559459,
#  100.4050978743316,
#  98.367871902109968,
#  99.303164700578819,
#  102.15250084922646,
#  102.28797575823599,
#  101.39782217909291,
#  99.476378291430819,
#  98.459260217658439,
#  100.37538441427279,
#  100.45540407647351,
#  97.853869739527156,
#  101.26257331975413,
#  102.3792353574794,
#  100.77021523892186,
#  100.07499584765554,
#  100.66931456203466,
#  98.187811436078007,
#  98.93869835682105,
#  100.56643473158873,
#  98.247367167479752,
#  98.908954738558236,
#  101.54329100648181,
#  104.92188918396577,
#  97.573501018548043,
# ...

# %%
pl.scatter(size, chimeans)

# %%
#figure out a way to store these values efficiently - all the means in the end should be plotted at the end of the HW
