# %%
from __future__ import print_function #Compatibility from Python_2 to Python_3

# %%
import numpy as np
import pylab as pl
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
np.random.rand(1)
# Out:
# array([ 0.17222014])

# %%
np.random.seed(400) #the seed checks and saves it - so any random number generated will be the same random number

# %%
np.random.rand(3)
# Out:
# array([ 0.66872891,  0.22599847,  0.85929874])

# %%
np.random.rand(4)
# Out:
# array([ 0.29039393,  0.14821583,  0.01204839,  0.77615409])

# %%
# np.random.rand? - gives a docstring to tell you what it is

# %%
np.random.rand(3,2)
# Out:
# array([[ 0.77615409,  0.40473613],
#        [ 0.85596041,  0.5387855 ],
#        [ 0.50968959,  0.37575594]])

# %%
uniform_array = np.random.rand(1000)

# %%
gaussian_array = np.random.randn(1000) #randn - gives standard normal distribution

# %%
#pl.hist?

# %%
pl.hist(uniform_array)
# Out:
# (array([  76.,  104.,  106.,  113.,   98.,   90.,  106.,   96.,  103.,  108.]),
#  array([  1.39627151e-04,   1.00082515e-01,   2.00025402e-01,
#           2.99968290e-01,   3.99911178e-01,   4.99854065e-01,
#           5.99796953e-01,   6.99739840e-01,   7.99682728e-01,
#           8.99625616e-01,   9.99568503e-01]),
#  <a list of 10 Patch objects>)

# %%
pl.hist(gaussian_array)
# Out:
# (array([   3.,   33.,   95.,  159.,  229.,  211.,  140.,   89.,   34.,    7.]),
#  array([-2.78629446, -2.22409786, -1.66190126, -1.09970466, -0.53750806,
#          0.02468854,  0.58688514,  1.14908174,  1.71127833,  2.27347493,
#          2.83567153]),
#  <a list of 10 Patch objects>)

# %%
uniform_array2 = np.random.rand(10000)

# %%
pl.hist(uniform_array2) #shows the distribution as a line
# Out:
# (array([ 1004.,  1021.,   990.,   995.,   971.,  1006.,  1014.,   964.,
#          1022.,  1013.]),
#  array([  1.68103293e-04,   1.00149096e-01,   2.00130089e-01,
#           3.00111082e-01,   4.00092075e-01,   5.00073068e-01,
#           6.00054061e-01,   7.00035054e-01,   8.00016046e-01,
#           8.99997039e-01,   9.99978032e-01]),
#  <a list of 10 Patch objects>)

# %%
pl.plot(uniform_array2, '.')

# %%
pl.plot(gaussian_array, '.')

# %%
gaussian_array2 = np.random.randn(10000)

# %%
pl.plot(gaussian_array2, '.')

# %%
gaussian_array3 = np.random.randn(2, 10000)

# %%
pl.plot(gaussian_array3[0],gaussian_array3[1], '.')

# %%
pl.figure(figsize = (10,10)) #size of the figure - x/y axis ratio
pl.plot(gaussian_array3[0],gaussian_array3[1], '.')
pl.xlim(-5,5) #see in a square block evenly on the axes
pl.ylim(-5,5)
# Out:
# (-5, 5)
